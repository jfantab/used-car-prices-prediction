# %% [markdown]
# Source: https://github.com/krishnaik06/Advanced-House-Price-Prediction-/blob/master/Feature%20Engineering.ipynb

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Imports preprocessing functions
# %run ./jlu_preprocessing.ipynb

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Algorithms

# %%
def predictPrice(X_train, X_test, Y_train, Y_test):
    linReg = LinearRegression().fit(X_train, Y_train)
    
    train_pred = linReg.predict(X_train)
    test_pred = linReg.predict(X_test)
    
    print("Train MSE: ", mean_squared_error(Y_train, train_pred))
    print("Test MSE: ", mean_squared_error(Y_test, test_pred))

# %% [markdown]
# ## Code

# %%
begin = time.time()
original_df = pd.read_csv('used_cars_data.csv')
end = time.time()

print("Time taken: ", end - begin)
# Out:
# /var/folders/kb/75nzr_1n56s5_rw0zrhwqhp00000gn/T/ipykernel_1061/1749011710.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv('used_cars_data.csv')
# Time taken:  147.53482699394226

# %%
# Sample a portion of the rows

begin = time.time()
df = original_df.sample(frac=0.30, replace=False, ignore_index=True)
end = time.time()

print("Time taken: ", end - begin)

print(df.shape)
df.head()
# Out:
# Time taken:  152.47291493415833
# (900012, 66)
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  2FMPK4J95LBB05676      40.6 in  NaN        NaN        NaN  SUV / Crossover
# 1  19XFC2E80LE024497      37.4 in  NaN        NaN        NaN            Sedan
# 2  WDDGJ5HB7DG036950        33 in  NaN        NaN        NaN            Coupe
# 3  1FT8X3BN4LED43748      33.5 in  NaN         --    81.9 in     Pickup Truck
# 4  KMHD84LF0LU106068      35.7 in  NaN        NaN        NaN            Sedan
#
#           cabin      city  city_fuel_economy  combine_fuel_economy  ...  \
# 0           NaN    Algona               21.0                   NaN  ...
# 1           NaN  Hartford               25.0                   NaN  ...
# 2           NaN     Plano               20.0                   NaN  ...
# 3  Extended Cab  Plymouth                NaN                   NaN  ...
# 4           NaN    Peoria               30.0                   NaN  ...
#
#    transmission                transmission_display  trimId  \
# 0             A                           Automatic  t87981
# 1             M                      6-Speed Manual  t88291
# 2             A                           Automatic  t44966
# 3             A                           Automatic  t86000
# 4           CVT  Continuously Variable Transmission  t85688
#
#            trim_name  vehicle_damage_category wheel_system  \
# 0            SEL AWD                      NaN          AWD
# 1    Sport Sedan FWD                      NaN          FWD
# 2        C 350 Coupe                      NaN          RWD
# 3   XLT SuperCab 4WD                      NaN          4WD
# 4  Limited Sedan FWD                      NaN          FWD
#
#   wheel_system_display wheelbase     width  year
# 0      All-Wheel Drive  112.2 in   85.8 in  2020
# 1    Front-Wheel Drive  106.3 in   70.8 in  2020
# 2     Rear-Wheel Drive  108.7 in   69.7 in  2013
# 3     Four-Wheel Drive    148 in  105.9 in  2020
# 4    Front-Wheel Drive  106.3 in   70.9 in  2020
#
# [5 rows x 66 columns]

# %% [markdown]
# #### Initial cleaning

# %%
df = cleanColumnsAndRows(df)
# Out:
# (900008, 50)

# %% [markdown]
# #### Process columns with years

# %%
df["year"] = processYears(df)
df.head()
# Out:
#                  vin back_legroom        body_type      city  \
# 0  2FMPK4J95LBB05676      40.6 in  SUV / Crossover    Algona
# 1  19XFC2E80LE024497      37.4 in            Sedan  Hartford
# 2  WDDGJ5HB7DG036950        33 in            Coupe     Plano
# 3  1FT8X3BN4LED43748      33.5 in     Pickup Truck  Plymouth
# 4  KMHD84LF0LU106068      35.7 in            Sedan    Peoria
#
#    city_fuel_economy  daysonmarket dealer_zip  \
# 0               21.0             5      50511
# 1               25.0            25       6120
# 2               20.0            44      75074
# 3                NaN           172       2360
# 4               30.0            51      85382
#
#                                          description engine_cylinders  \
# 0                                                NaN               I4
# 1  [!@@Additional Info@@!]Cloth Seat Trim,Radio: ...               I4
# 2  Located in Plano, Texas, Plano Pre-Owned Auto ...               V6
# 3  Colonial Ford of Plymouth, Our sales teams wil...               V8
# 4  Want our best deal on this Hyundai? Don't have...               I4
#
#    engine_displacement  ...                 torque transmission  \
# 0               2000.0  ...  280 lb-ft @ 3,000 RPM            A
# 1               2000.0  ...  138 lb-ft @ 4,200 RPM            M
# 2               3500.0  ...  273 lb-ft @ 3,500 RPM            A
# 3               7300.0  ...  430 lb-ft @ 3,800 RPM            A
# 4               2000.0  ...  132 lb-ft @ 4,500 RPM          CVT
#
#                  transmission_display  trimId          trim_name wheel_system  \
# 0                           Automatic  t87981            SEL AWD          AWD
# 1                      6-Speed Manual  t88291    Sport Sedan FWD          FWD
# 2                           Automatic  t44966        C 350 Coupe          RWD
# 3                           Automatic  t86000   XLT SuperCab 4WD          4WD
# 4  Continuously Variable Transmission  t85688  Limited Sedan FWD          FWD
#
#   wheel_system_display wheelbase     width  year
# 0      All-Wheel Drive  112.2 in   85.8 in    70
# 1    Front-Wheel Drive  106.3 in   70.8 in    70
# 2     Rear-Wheel Drive  108.7 in   69.7 in    63
# 3     Four-Wheel Drive    148 in  105.9 in    70
# 4    Front-Wheel Drive  106.3 in   70.9 in    70
#
# [5 rows x 50 columns]

# %% [markdown]
# #### Standardize columns of differing data types

# %%
df, price_col = convertColumnsToNumericalAndStandardize(df)
df.head()
# Out:
# year
#    body_type      city  city_fuel_economy  daysonmarket  engine_cylinders  \
# 0   0.078626 -1.679077      -2.111158e-01     -0.651040         -0.831436
# 1   0.863385 -0.415102       2.824262e-01     -0.468024         -0.831436
# 2  -3.060411  0.744057      -3.345013e-01     -0.294158          0.704881
# 3  -0.706133  0.759471       1.315060e-15      0.877146          1.253566
# 4   0.863385  0.694731       8.993536e-01     -0.230103         -0.831436
#
#    engine_displacement  engine_type  exterior_color  franchise_dealer  \
# 0            -0.738657    -0.831436       -1.683763          0.484166
# 1            -0.738657    -0.831436        1.625607          0.484166
# 2             0.406776     0.704881        1.456004         -2.065409
# 3             3.308538     1.253566       -1.660868          0.484166
# 4            -0.738657    -0.831436        0.987206          0.484166
#
#    franchise_make  ...  model_name  savings_amount  seller_rating   sp_name  \
# 0       -0.825886  ...   -0.625338       -0.515110       1.431866  0.533579
# 1       -0.566914  ...   -0.944581       -0.515110      -0.204145  0.234136
# 2        1.375380  ...   -1.187675       -0.270842      -0.138705  0.801070
# 3       -0.825886  ...   -0.461323       -0.515110       0.322223 -0.931400
# 4       -0.502171  ...   -0.610694       -0.515110      -0.174400  0.171646
#
#    transmission  transmission_display  trim_name  wheel_system  \
# 0     -0.390670              0.626877   0.496307     -0.194193
# 1      3.589087             -1.110251   0.888673      0.538449
# 2     -0.390670              0.626877  -0.953855      1.271092
# 3     -0.390670              0.626877   1.413200     -1.659478
# 4      0.935915              0.750958   0.032460      0.538449
#
#    wheel_system_display      year
# 0             -1.183673  0.545981
# 1              0.529667  0.545981
# 2              1.386337 -1.137117
# 3             -0.327003  0.545981
# 4              0.529667  0.545981
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Run algorithm

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

predictPrice(X_train, X_test, Y_train, Y_test)
# Out:
# Train MSE:  162874164.6093245
# Test MSE:  158103883.20438397
