# %% [markdown]
# Source: https://github.com/krishnaik06/Advanced-House-Price-Prediction-/blob/master/Feature%20Engineering.ipynb

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Code

# %% [markdown]
# #### Read file and extract random sample

# %%
begin = time.time()
original_df = pd.read_csv('used_cars_data.csv')
end = time.time()

print("Time taken: ", end - begin)
# Out:
# /var/folders/kb/75nzr_1n56s5_rw0zrhwqhp00000gn/T/ipykernel_51393/1749011710.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv('used_cars_data.csv')
# Time taken:  226.17842507362366

# %%
# Sample a portion of the rows

PERCENT = 0.60

begin = time.time()
sampled_df = original_df.sample(frac=PERCENT, replace=False, ignore_index=True)
end = time.time()

print("Time taken: ", end - begin)
# Out:
# Time taken:  27.870720148086548

# %%
df = sampled_df

print(df.shape)
df.head()
# Out:
# (1800024, 66)
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ML32A5HJ6LH004725        34 in  NaN        NaN        NaN        Hatchback
# 1  JF2GPACC2FH254276      35.4 in  NaN        NaN        NaN  SUV / Crossover
# 2  1C6RR7TM3JS321449      40.3 in  NaN         --    76.3 in     Pickup Truck
# 3  1N4BL4BV9LC265248      35.2 in  NaN        NaN        NaN            Sedan
# 4  2C4RDGCG4KR682497      36.5 in  NaN        NaN        NaN          Minivan
#
#       cabin           city  city_fuel_economy  combine_fuel_economy  ...  \
# 0       NaN     Norristown               36.0                   NaN  ...
# 1       NaN         Naples               26.0                   NaN  ...
# 2  Crew Cab       Billings               19.0                   NaN  ...
# 3       NaN     Cookeville               28.0                   NaN  ...
# 4       NaN  Hollidaysburg               12.0                   NaN  ...
#
# ...

# %% [markdown]
# #### Initial cleaning

# %%
# Imports preprocessing functions
# %run ./jlu_preprocessing.ipynb

# %%
df, price_col = cleanColumnsAndRows(df)
# Out:
# (1800006, 56)

# %% [markdown]
# #### Standardize columns of differing data types

# %%
df = convertColumnsToNumericalAndStandardize(df, standardizer)
df.head()
# Out:
# year
#    back_legroom  body_type  city_fuel_economy  daysonmarket  engine_cylinders  \
# 0     -0.982628  -2.316823           1.686943      0.943691         -1.017189
# 1     -0.599228   0.095548           0.445652     -0.431653         -1.444084
# 2      0.742671  -0.708576          -0.423252     -0.495836          1.010564
# 3     -0.653999   0.899672           0.693910     -0.321626         -0.803741
# 4     -0.297985  -1.512700          -1.292156     -0.505005          1.330735
#
#    engine_displacement  exterior_color     fleet  frame_damaged  \
# 0            -1.325734       -1.392213 -0.354759      -0.070829
# 1            -0.716588        0.615871 -0.354759      -0.070829
# 2             0.044843       -1.228314 -0.354759      -0.070829
# 3            -0.335872        1.209525 -0.354759      -0.070829
# 4             0.501703       -1.405658  2.818817      -0.070829
#
#    franchise_make  ...  theft_title    torque  transmission  \
# ...

# %% [markdown]
# ## Testing

# %% [markdown]
# Functions

# %%
def runModel(df, model):
    X_train, X_test, Y_train, Y_test = train_test_split(df, price_col, test_size=0.2)

    # - - - - Fit and Predict - - - -
    clf = model.fit(X_train, Y_train)
    train_pred = clf.predict(X_train)
    test_pred = clf.predict(X_test)

    print("Train RMSE: ", mean_squared_error(Y_train, train_pred, squared=False))
    print("Test RMSE: ", mean_squared_error(Y_test, test_pred, squared=False))

# %%
def crossVal(model, data, labels, scoring='neg_mean_squared_error'):
    folds = 10
    
    cv = cross_validate(model, data, labels, cv=folds, scoring=scoring,
                        return_train_score=True, n_jobs=-1, error_score='raise')
    
    test_scores = cv['test_score']
    test_scores = [-1 * s for s in test_scores]
    
    plt.figure(figsize=(4,4))
    plt.plot(test_scores)
    plt.title("RMSE Across K Folds of Cross Validation")
    plt.xlabel("Folds")
    plt.ylabel("RMSE")
    plt.show()

    return cv

# %%
def runModelCrossVal(model, df, price_col, cols_to_drop=[]):
    df = df.drop(columns=cols_to_drop, axis=1)
    cv = crossVal(model, df, price_col, scoring='neg_root_mean_squared_error')
    print("Mean Train RMSE: ", np.mean(cv["train_score"]) * -1)
    print("Mean Test RMSE: ", np.mean(cv["test_score"]) * -1)

# %%
def tuneParams(data, labels, params):
    folds = 5
    scores = []
    
    for param in params:
        # model = Lasso(alpha=param, selection='random', max_iter=5000) 
        # model = ElasticNet(alpha=0.2, l1_ratio=param)
        model = Lasso(alpha=param)
        cv = cross_validate(model, data, labels, cv=folds, scoring='neg_root_mean_squared_error', 
                            n_jobs=-1, error_score='raise')
        
        test_scores = cv['test_score']
        test_scores = [-1 * s for s in test_scores]
        
        score = np.mean(test_scores)
        scores.append(score)
        
        print(param, " | ", score)
    
    plt.figure(figsize=(4,4))
    plt.plot(params, scores)
    plt.show()

# %% [markdown]
# > Tuning takes >30 minutes to run, very computationally expensive

# %% [markdown]
# Lasso Tuning

# %%
# alpha params
# params = np.arange(.05,.11,.01)
params = np.arange(0.1,1.1,0.1)
tuneParams(df, price_col, params)
# Out:
# 0.1  |  14407.631775768776
# 0.2  |  14407.493840843666
# 0.30000000000000004  |  14407.351953717845
# 0.4  |  14407.21387970661
# 0.5  |  14407.075453980337
# 0.6  |  14406.937405821087
# 0.7000000000000001  |  14406.800083686929
# 0.8  |  14406.66295567838
# 0.9  |  14406.526042147281
# 1.0  |  14406.389271919019

# %% [markdown]
# Elastic Net Tuning

# %%
# alpha params
# params = np.arange(0.1,1.1,0.1)
# tuneParams(df, price_col, params)

# %%
# l1 ratio params, alpha=0.6
params = np.arange(0.1,1.1,0.1)
tuneParams(df, price_col, params)
# Out:
# 0.1  |  13513.3468909822
# 0.2  |  13500.482297975006
# 0.30000000000000004  |  13492.435399661685
# 0.4  |  13491.715725016536
# 0.5  |  13502.480342195497
# 0.6  |  13531.831198889366
# 0.7000000000000001  |  13592.621894578322
# 0.8  |  13709.870982087736
# 0.9  |  13937.318571408072
# 1.0  |  14407.493840843666

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Original

# %%
runModelCrossVal(LinearRegression(), df, price_col) # SimpleImputer with median
# Out:
# Mean Train RMSE:  12560.448548113789
# Mean Test RMSE:  14097.543764459037

# %%
runModelCrossVal(LinearRegression(), df, price_col)
# Out:
# Mean Train RMSE:  12793.690094382775
# Mean Test RMSE:  14240.548741734292

# %% [markdown]
# Outliers removed

# %%
outlier_cols = ["daysonmarket", "seller_rating", "highway_fuel_economy"]
runModelCrossVal(LinearRegression(), df, price_col, outlier_cols) # SimpleImputer with median
# Out:
# Mean Train RMSE:  12609.098451588068
# Mean Test RMSE:  14177.112272820148

# %%
outlier_cols = ["daysonmarket", "seller_rating", "highway_fuel_economy"]
runModelCrossVal(LinearRegression(), df, price_col, outlier_cols)
# Out:
# Mean Train RMSE:  12849.279081695662
# Mean Test RMSE:  14335.205560092994

# %% [markdown]
# Boolean features removed

# %%
bool_cols = ["isCab", "is_new", "fleet", "isCab", "salvage", "frame_damaged", "has_accidents"]
runModelCrossVal(LinearRegression(), df, price_col, bool_cols) #SimpleImputer with median
# Out:
# Mean Train RMSE:  13003.234194011502
# Mean Test RMSE:  15192.681467351145

# %%
bool_cols = ["isCab", "is_new", "fleet", "isCab", "salvage", "frame_damaged", "has_accidents"]
runModelCrossVal(LinearRegression(), df, price_col, bool_cols)
# Out:
# Mean Train RMSE:  13201.43770233453
# Mean Test RMSE:  15267.671295872182

# %% [markdown]
# ## Lasso

# %% [markdown]
# Original

# %%
model = Lasso(selection='random', max_iter=5000)
runModelCrossVal(model, df, price_col) # SimpleImputer with median
# Out:
# Mean Train RMSE:  12560.455714022195
# Mean Test RMSE:  14096.491112522528

# %%
model = Lasso(selection='random', max_iter=5000)
runModelCrossVal(model, df, price_col)
# Out:
# Mean Train RMSE:  12793.696757559945
# Mean Test RMSE:  14239.579148154653

# %%
model = Lasso(alpha=0.5, selection='random', max_iter=3000)
runModelCrossVal(model, df, price_col) # SimpleImputer with median
# Out:
# Mean Train RMSE:  12560.4503307886
# Mean Test RMSE:  14096.993473272309

# %%
model = Lasso(alpha=0.5, selection='random', max_iter=3000)
runModelCrossVal(model, df, price_col)
# Out:
# Mean Train RMSE:  12793.691747264842
# Mean Test RMSE:  14240.0621020184

# %% [markdown]
# Outliers Removed

# %%
model = Lasso(alpha=0.5, selection='random', max_iter=3000)
outlier_cols = ["daysonmarket", "city_fuel_economy", "highway_fuel_economy"]
runModelCrossVal(model, df, price_col, outlier_cols)
# Out:
# Mean Train RMSE:  12827.26161565513
# Mean Test RMSE:  14310.382314948172

# %% [markdown]
# ## ElasticNet

# %% [markdown]
# Original

# %%
model = ElasticNet(alpha=0.6)
runModelCrossVal(model, df, price_col) # SimpleImputer with median
# Out:
# Mean Train RMSE:  13407.451682325109
# Mean Test RMSE:  13613.224902083606

# %%
model = ElasticNet(alpha=0.6)
runModelCrossVal(model, df, price_col)
# Out:
# Mean Train RMSE:  13574.343369306298
# Mean Test RMSE:  13752.812168098593

# %% [markdown]
# Outliers Removed

# %%
model = ElasticNet(alpha=0.6)
outlier_cols = ["daysonmarket", "city_fuel_economy", "highway_fuel_economy"]
runModelCrossVal(model, df, price_col, outlier_cols)
# Out:
# Mean Train RMSE:  13593.589555374341
# Mean Test RMSE:  13774.04862910097

# %% [markdown]
# Booleans Removed

# %%
model = ElasticNet(alpha=0.6)
bool_cols = ["is_new", "fleet", "isCab", "salvage", "frame_damaged", "has_accidents"]
runModelCrossVal(model, df, price_col, bool_cols)
# Out:
# Mean Train RMSE:  14002.909050092605
# Mean Test RMSE:  14307.107890644946
