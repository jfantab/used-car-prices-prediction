# %% [markdown]
# ## Sources:
# - https://github.com/krishnaik06/Advanced-House-Price-Prediction-
# - https://towardsdatascience.com/how-to-perform-feature-selection-for-regression-problems-c928e527bbfa

# %%
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import mutual_info_regression, f_regression

from IPython.display import clear_output

# %run ./jlu_preprocessing.ipynb

# %% [markdown]
# ## Functions

# %%
# Plotting Mutual Information of 30 features against target column price on sample of 30% of data

def calculateMI(df, price_col):   
    PERCENT = 0.30
    size = df.shape[0]
    indices = np.random.choice(size, math.floor(size*PERCENT))
    x, y = df.iloc[indices,:], price_col.iloc[indices]
    y = np.array(y)
    
    scores = []
    for i, c in enumerate(x.columns):
        col = np.array(x[c]).reshape(-1,1)
        score = mutual_info_regression(col, y)
        scores.append((c, score))
        
        clear_output(wait=True)
        print(i, " | ", c, ": ", score)
    
    return scores

# %%
def plotFn(df, label):
    arr = convertMeasurementStrings(df, label)
    
    plt.figure(figsize=(5,4))
    plt.hist(arr)
    plt.title(f"Distribution of Values For {label}")
    plt.xlabel(label)
    plt.ylabel("Frequencies")
    plt.show()

# %% [markdown]
# ## Reading in File and Preprocessing

# %%
begin = time.time()
original_df = pd.read_csv('used_cars_data.csv')
end = time.time()

print("Time taken: ", end - begin)
# Out:
# /var/folders/kb/75nzr_1n56s5_rw0zrhwqhp00000gn/T/ipykernel_21488/1749011710.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv('used_cars_data.csv')
# Time taken:  183.694806098938

# %%
df = original_df
df.head()
# Out:
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# 2   NaN  Guaynabo               17.0                   NaN  ...             M
# 3   NaN  San Juan                NaN                   NaN  ...             A
# 4   NaN  San Juan                NaN                   NaN  ...             A
#
#           transmission_display  trimId     trim_name  vehicle_damage_category  \
# 0  9-Speed Automatic Overdrive  t83804  Latitude FWD                      NaN
# 1  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
# 2               6-Speed Manual  t58994          Base                      NaN
# 3  8-Speed Automatic Overdrive  t86074    V6 HSE AWD                      NaN
# 4  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
#
#   wheel_system wheel_system_display wheelbase    width  year
# 0          FWD    Front-Wheel Drive  101.2 in  79.6 in  2019
# 1          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
# 2          AWD      All-Wheel Drive  104.3 in  78.9 in  2016
# 3          AWD      All-Wheel Drive    115 in  87.4 in  2020
# 4          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
#
# [5 rows x 66 columns]

# %%
##### Preprocessing
df, price_col = cleanColumnsAndRows(df)
df = convertColumnsToNumericalAndStandardize(df, standardizer)

df.head()
# Out:
# year
#    back_legroom  body_type  city_fuel_economy  daysonmarket  engine_cylinders  \
# 0     -0.674821   0.095956          -0.175286      4.095563         -0.803948
# 1      0.137797   0.095956          -0.175286      1.202570         -0.803948
# 2     -0.593559   0.900248          -0.670468     10.625462         -1.444148
# 3      0.002361   0.095956          -0.175286      1.101544          0.903252
# 4      0.137797   0.095956          -0.175286      0.559682         -0.803948
#
#    engine_displacement  engine_type  exterior_color     fleet  frame_damaged  \
# 0            -1.249186    -0.803948        1.110112 -0.354506      -0.070772
# 1            -0.716506    -0.803948        0.259950 -0.354506      -0.070772
# 2            -0.336021    -1.444148        0.298938 -0.354506      -0.070772
# 3             0.044465     0.903252       -0.665916 -0.354506      -0.070772
# 4            -0.716506    -0.803948        0.259950 -0.354506      -0.070772
#
#    ...  theft_title    torque  transmission  transmission_display  trim_name  \
# 0  ...    -0.041934 -0.824244     -0.401772              0.425088   0.032846
# 1  ...    -0.041934  0.097957     -0.401772              0.425088   0.438212
# 2  ...    -0.041934  0.353225      5.379857             -1.144428  -1.026740
# 3  ...    -0.041934  0.701971     -0.401772             -0.135454   1.223364
# 4  ...    -0.041934  0.097957     -0.401772              0.425088   0.438212
#
#    wheel_system  wheel_system_display  wheelbase     width      year
# 0      0.676995              0.703380  -1.181982  0.353710  0.307563
# 1     -0.135281             -1.261386  -0.571057  1.243822  0.550052
# 2     -0.135281             -1.261386  -0.881368  0.244398 -0.419903
# 3     -0.135281             -1.261386   0.078657  1.493677  0.550052
# 4     -0.135281             -1.261386  -0.571057  1.243822  0.550052
#
# [5 rows x 40 columns]

# %%
# Printing out data types of each column

# col_dtypes = dict()
# for col in df.columns:
#     d = df[col].dropna(axis=0)
    
#     if len(d) > 0:
#         print(col, ": ", type(d.iloc[0]))

# %% [markdown]
# ## Investigating Percentages of non-NaNs in Features

# %%
# percent_non_nans = []
# cols = original_df.columns

# for c in cols:
#     cur_feat = original_df[c]
#     size = len(cur_feat)

#     cnt = 0
#     for val in cur_feat:
#         if not pd.isnull(val):
#             cnt += 1
    
#     percent_non_nans.append(round(cnt/size, 3))

# %%
# NUM_ROWS, NUM_COLS = 3, 2
# fig, ax = plt.subplots(NUM_ROWS, NUM_COLS, figsize=(25, 10))
# increment = 11
# cols = original_df.columns
# size = len(cols)

# ind = 0
# ind2 = 0
# for i in range(0, size, increment):
#     if ind == NUM_COLS:
#         ind2 += 1
#         ind = 0
    
#     ax[ind2, ind].barh(np.arange(increment), percent_non_nans[i:i+increment], align='center');
#     ax[ind2, ind].set_yticks(np.arange(increment), cols[i:i+increment])
#     ax[ind2, ind].set_xlabel("Percentage of non-NaN values")
    
#     ind += 1
    
# plt.tight_layout()
# plt.show()

# %%
# increment = 11
# cols = original_df.columns
# size = len(cols)

# for i in range(0, size, increment):
#     plt.figure(figsize=(4,4))
#     plt.barh(np.arange(increment), percent_non_nans[i:i+increment], align='center');
#     plt.yticks(np.arange(increment), cols[i:i+increment])
#     plt.xlabel("Percentage of non-NaN values")
#     plt.show()

# %% [markdown]
# ## Feature Selection

# %%
# Only compute ONCE

# scores = calculateMI(df, price_col)

# %%
# increment = 10
# size = len(scores)
# Y = [s[1][0] for s in scores]

# for i in range(0, size, increment):
#     plt.figure(figsize=(4,4))
#     plt.barh(np.arange(1,increment+1), Y[i:i+increment])
#     plt.title("Mutual Information of Each Feature vs Target Column (Price)")
#     plt.yticks(np.arange(1,increment+1), df.columns[i:i+increment])
#     plt.xlabel("Mutual Information")
#     plt.show()

# %%
from sklearn.preprocessing import StandardScaler
price_col_ = StandardScaler().fit_transform(price_col.to_numpy().reshape(-1,1)).ravel()

f_stat, _ = f_regression(df, price_col_)

X = np.arange(0, len(f_stat))

plt.figure(figsize=(12,4))
plt.xticks(np.arange(len(f_stat)))
plt.bar(X, f_stat);
plt.title("F-Statistic Scores For Each Column")
plt.xlabel("Columns")
plt.ylabel("F-Statistic")
plt.show()

# %% [markdown]
# ## Investigating Outliers

# %% [markdown]
# Plots

# %%
def getOutlierPercentages(df):

    vals = []
    
    for label in df.columns:
        lst = df[label]
        lower_quantile = days.quantile(q=0.25)
        upper_quantile = days.quantile(q=0.75)
        median = lst.median()
        lst_ = list(filter(lambda x: x >= lower_quantile and x <= upper_quantile, lst))

        og_len = len(lst)
        new_len = len(lst_)
        percent_outlier = (og_len - new_len) / (og_len)
        
        vals.append(percent_outlier)
        
        clear_output(wait=True)
        print(label)
    
    return vals

# %%
# NUM_ROWS, NUM_COLS = 3, 2
# fig, ax = plt.subplots(NUM_ROWS, NUM_COLS, figsize=(25, 10))
# increment = 11
# cols = original_df.columns
# size = len(cols)

# ind = 0
# ind2 = 0
# for i in range(0, size, increment):
#     if ind == NUM_COLS:
#         ind2 += 1
#         ind = 0
    
#     ax[ind2, ind].barh(np.arange(increment), percent_non_nans[i:i+increment], align='center');
#     ax[ind2, ind].set_yticks(np.arange(increment), cols[i:i+increment])
#     ax[ind2, ind].set_xlabel("Percentage of non-NaN values")
    
#     ind += 1
    
# plt.tight_layout()
# plt.show()

# %%
# INCREMENT = 12
# NUM_ROWS, NUM_COLS = 2,2
# fig, ax = plt.subplots(NUM_ROWS, NUM_COLS, figsize=(25, 10))

# ind, ind2 = 0, 0
# for i in range(0, len(vals), INCREMENT):
#     if ind2 == NUM_COLS:
#         ind2 = 0
#         ind += 1
        
#     if (i + INCREMENT + 1) > len(vals):
#         inc = len(vals) - i
#     else:
#         inc = INCREMENT
    
    
#     ax[ind, ind2].barh(np.arange(1, inc+1), vals[i:i+inc])
#     ax[ind, ind2].set_xticks(np.arange(0.0,1.1,0.1))
#     ax[ind, ind2].set_yticks(np.arange(1, inc+1), df.columns[i:i+inc])
    
#     ind2 += 1

# plt.show()

# %%
df.columns
# Out:
# Index(['back_legroom', 'body_type', 'city_fuel_economy', 'daysonmarket',
#        'engine_cylinders', 'engine_displacement', 'engine_type',
#        'exterior_color', 'fleet', 'frame_damaged', 'franchise_make',
#        'front_legroom', 'fuel_tank_volume', 'has_accidents', 'height',
#        'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab',
#        'is_new', 'length', 'make_name', 'maximum_seating', 'mileage',
#        'model_name', 'power', 'salvage', 'savings_amount', 'seller_rating',
#        'sp_name', 'theft_title', 'torque', 'transmission',
#        'transmission_display', 'trim_name', 'wheel_system',
#        'wheel_system_display', 'wheelbase', 'width', 'year'],
#       dtype='object')

# %%
columns = ["back_legroom", "height", "wheelbase", "width", "mileage", "seller_rating", "highway_fuel_economy", "city_fuel_economy", "daysonmarket"]
vals = getOutlierPercentages(df[columns])

plt.barh(np.arange(1, len(vals)+1), vals)
plt.xticks(np.arange(0.0,1.1,0.1))
plt.yticks(np.arange(1, len(columns)+1), columns)
plt.show()
    
# INCREMENT = 10
# for i in range(0, len(vals), inc):
#     plt.barh(np.arange(1, inc+1), vals[i:i+inc])
#     plt.xticks(np.arange(0.0,1.1,0.1))
#     plt.yticks(np.arange(1, inc+1), df.columns[i:i+inc])
#     plt.show()
    
#     ind2 += 1
# Out:
# daysonmarket

# %% [markdown]
# Manual Investigation

# %%
def describeStatistics(label):
    print("original_df:\n", original_df[label].describe(), "\n")
    print("df:\n", df[label].describe(), "\n")

    lst = df[label]
    lower_quantile = days.quantile(q=0.25)
    upper_quantile = days.quantile(q=0.75)
    median = lst.median()
    lst_ = list(filter(lambda x: x >= lower_quantile and x <= upper_quantile, lst))

    og_len = len(lst)
    new_len = len(lst_)
    percent_outlier = (og_len - new_len) / (og_len)
    
    print("Original length: ", og_len, " | Filtered length: ", new_len, " | % Outliers: ",  round(percent_outlier,2))

# %%
describeStatistics("daysonmarket")
# Out:
# original_df:
#  count    3.000040e+06
# mean     7.605973e+01
# std      1.088839e+02
# min      0.000000e+00
# 25%      1.400000e+01
# 50%      3.500000e+01
# 75%      8.200000e+01
# max      3.599000e+03
# Name: daysonmarket, dtype: float64
#
# df:
#  count    3.000000e+06
# mean    -1.322557e-17
# std      1.000000e+00
# min     -6.985403e-01
# 25%     -5.699628e-01
# 50%     -3.770966e-01
# 75%      5.455637e-02
# max      3.235506e+01
# Name: daysonmarket, dtype: float64
#
# Original length:  3000000  | Filtered length:  1555527  | % Outliers:  0.48

# %%
describeStatistics("city_fuel_economy")
# Out:
# original_df:
#  count    2.508755e+06
# mean     2.269325e+01
# std      8.807024e+00
# min      7.000000e+00
# 25%      1.800000e+01
# 50%      2.100000e+01
# 75%      2.600000e+01
# max      1.270000e+02
# Name: city_fuel_economy, dtype: float64
#
# df:
#  count    3.000000e+06
# mean    -1.760299e-16
# std      1.000000e+00
# min     -1.908424e+00
# 25%     -5.466728e-01
# 50%     -1.752861e-01
# 75%      3.198961e-01
# max      1.294704e+01
# Name: city_fuel_economy, dtype: float64
#
# Original length:  3000000  | Filtered length:  1396967  | % Outliers:  0.53

# %%
describeStatistics("savings_amount")
# Out:
# original_df:
#  count    3.000040e+06
# mean     5.509768e+02
# std      1.079448e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      7.850000e+02
# max      1.474140e+05
# Name: savings_amount, dtype: float64
#
# df:
#  count    3.000000e+06
# mean    -2.222578e-17
# std      1.000000e+00
# min     -5.104238e-01
# 25%     -5.104238e-01
# 50%     -5.104238e-01
# 75%      2.168007e-01
# max      1.360540e+02
# Name: savings_amount, dtype: float64
#
# Original length:  3000000  | Filtered length:  2126313  | % Outliers:  0.29

# %%
describeStatistics("highway_fuel_economy")
# Out:
# original_df:
#  count    2.508755e+06
# mean     2.947337e+01
# std      7.769252e+00
# min      1.000000e+01
# 25%      2.500000e+01
# 50%      2.900000e+01
# 75%      3.300000e+01
# max      1.270000e+02
# Name: highway_fuel_economy, dtype: float64
#
# df:
#  count    3.000000e+06
# mean     1.004897e-16
# std      1.000000e+00
# min     -2.729223e+00
# 25%     -6.185439e-01
# 50%     -5.569626e-02
# 75%      3.664395e-01
# max      1.373407e+01
# Name: highway_fuel_economy, dtype: float64
#
# Original length:  3000000  | Filtered length:  1105765  | % Outliers:  0.63

# %%
describeStatistics("wheelbase")
# Out:
# original_df:
#  count      2840771
# unique         483
# top       106.3 in
# freq        193512
# Name: wheelbase, dtype: object
#
# df:
#  count    3.000000e+06
# mean     8.613673e-17
# std      1.000000e+00
# min     -1.298349e+00
# 25%     -7.165154e-01
# 50%     -2.898377e-01
# 75%      4.568482e-01
# max      3.375711e+00
# Name: wheelbase, dtype: float64
#
# Original length:  3000000  | Filtered length:  847373  | % Outliers:  0.72

# %% [markdown]
# ## Box Plots of Features

# %%
columns = ["back_legroom", "height", "wheelbase", "width", "mileage", "seller_rating", "highway_fuel_economy", "city_fuel_economy", "daysonmarket"]

# Box plot
df_ = original_df
df_, _ = cleanColumnsAndRows(df_)
df_ = convertColumnsToNumericalAndStandardize(df_, minMaxScaler)
df_ = df[columns]
# Out:
# year

# %%
# Old code arranging box plots in a grid format

# NUM_ROWS, NUM_COLS = 2,2
# fig, ax = plt.subplots(NUM_ROWS, NUM_COLS, figsize=(50, 30))
# increment = 10
# cols = df_.columns
# size = len(cols)

# ind = 0
# ind2 = 0
# for i in range(0, size, increment):
#     if ind == NUM_COLS:
#         ind2 += 1
#         ind = 0
    
#     ax[ind2, ind].boxplot(df_.loc[i:i+increment,:], vert=False);
#     ax[ind2, ind].set_yticks(np.arange(increment), cols[i:i+increment])
    
#     ind += 1
    
# plt.tight_layout()
# plt.show()

# %%
df_.head()
# Out:
#    back_legroom    height  wheelbase     width   mileage  seller_rating  \
# 0     -0.674821  0.109994  -1.181982  0.353710 -0.411858      -2.885840
# 1      0.137797  0.322245  -0.571057  1.243822 -0.411844      -2.493576
# 2     -0.593559 -1.064463  -0.881368  0.244398 -0.298606       0.137459
# 3      0.002361  1.029749   0.078657  1.493677 -0.411803      -2.493576
# 4      0.137797  0.322245  -0.571057  1.243822 -0.411858      -2.493576
#
#    highway_fuel_economy  city_fuel_economy  daysonmarket
# 0             -0.055696          -0.175286      4.095563
# 1             -0.055696          -0.175286      1.202570
# 2             -0.899968          -0.670468     10.625462
# 3             -0.055696          -0.175286      1.101544
# 4             -0.055696          -0.175286      0.559682

# %%
# Box plots of dataframe standardized with MinMaxScaler

# increment = 10
# cols = df_.columns
# size = len(cols)
# for i in range(0, size, increment):
#     cols_subset = cols[i:i+increment]
#     plt.boxplot(df_[cols_subset], vert=False);
#     plt.yticks(np.arange(1,increment+1), cols_subset)
#     plt.show()

plt.boxplot(df_, vert=False)
plt.yticks(np.arange(1, len(df_.columns)+1), df_.columns)
plt.xlim([-10,10])
plt.title("Box Plots For Chosen Numerical Features")
plt.show()

# %% [markdown]
# ## Feature Exploration

# %%
plt.figure(figsize=(4,4))
plt.title("Distribution of Seller Ratings for Used Cars")
plt.xlabel("Seller Ratings")
plt.ylabel("Frequencies")
plt.hist(original_df["seller_rating"].dropna().to_numpy());
plt.show()

# %%
# Exploring range of prices in bins of 1000

plt.figure(figsize=(5,3))
plt.xlim(0,125000)
plt.title("Distribution of Used Car Prices")
plt.xlabel("Prices")
plt.ylabel("Frequencies")
plt.hist(original_df["price"].dropna(), bins=1000);
plt.show()

# %%
# Explore fuel types

fuel_type = original_df["fuel_type"].dropna(axis=0)

plt.figure(figsize=(5,5))
plt.hist(fuel_type, align='left', orientation='horizontal');
plt.title("Distribution of Car Fuel Types")
plt.xlabel("Frequencies")
plt.ylabel("Fuel Types")
plt.show()

# %%
plotFn(original_df, "back_legroom")

# %%
plotFn(original_df, "front_legroom")

# %%
plotFn(original_df, "height")

# %%
plotFn(original_df, "width")

# %%
plotFn(original_df, "length")

# %%
plotFn(original_df, "wheelbase")
