# %% [markdown]
# ## Sources:
# - https://github.com/krishnaik06/Advanced-House-Price-Prediction-

# %%
import math
import time
import heapq
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import mutual_info_regression, SelectKBest, f_regression

from IPython.display import clear_output

# %run ./jlu_preprocessing.ipynb

# %% [markdown]
# ## Functions

# %%
# Plotting Mutual Information of 30 features against target column price on sample of 30% of data

def calculateMI(df, price_col):   
    PERCENT = 0.30
    size = df.shape[0]
    indices = np.random.choice(size, math.floor(size*PERCENT))
    x, y = df.iloc[indices,:], price_col.iloc[indices]
    y = np.array(y)
    
    scores = []
    for i, c in enumerate(x.columns):
        col = np.array(x[c]).reshape(-1,1)
        score = mutual_info_regression(col, y)
        scores.append((c, score))
        
        clear_output(wait=True)
        print(i, " | ", c, ": ", score)
    
    return scores

# %% [markdown]
# ## Testing

# %% [markdown]
# Reading in File

# %%
begin = time.time()
original_df = pd.read_csv('used_cars_data.csv')
end = time.time()

print("Time taken: ", end - begin)
# Out:
# /var/folders/kb/75nzr_1n56s5_rw0zrhwqhp00000gn/T/ipykernel_62200/1749011710.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv('used_cars_data.csv')
# Time taken:  214.55862498283386

# %%
df = original_df
df.head()
# Out:
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# 2   NaN  Guaynabo               17.0                   NaN  ...             M
# 3   NaN  San Juan                NaN                   NaN  ...             A
# 4   NaN  San Juan                NaN                   NaN  ...             A
#
#           transmission_display  trimId     trim_name  vehicle_damage_category  \
# 0  9-Speed Automatic Overdrive  t83804  Latitude FWD                      NaN
# 1  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
# 2               6-Speed Manual  t58994          Base                      NaN
# 3  8-Speed Automatic Overdrive  t86074    V6 HSE AWD                      NaN
# 4  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
#
#   wheel_system wheel_system_display wheelbase    width  year
# 0          FWD    Front-Wheel Drive  101.2 in  79.6 in  2019
# 1          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
# 2          AWD      All-Wheel Drive  104.3 in  78.9 in  2016
# 3          AWD      All-Wheel Drive    115 in  87.4 in  2020
# 4          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Source: https://towardsdatascience.com/how-to-perform-feature-selection-for-regression-problems-c928e527bbfa

# %%
# Printing out data types of each column

# col_dtypes = dict()
# for col in df.columns:
#     d = df[col].dropna(axis=0)
    
#     if len(d) > 0:
#         print(col, ": ", type(d.iloc[0]))

# %%
# Preprocessing
df, price_col = cleanColumnsAndRows(df)
df = convertColumnsToNumericalAndStandardize(df, standardizer)

df.head()
# Out:
# year
#    back_legroom  body_type  city_fuel_economy  daysonmarket  engine_cylinders  \
# 0     -0.674821   0.095956      -8.822786e-16      4.095563         -0.803948
# 1      0.137797   0.095956      -8.822786e-16      1.202570         -0.803948
# 2     -0.593559   0.900248      -7.069242e-01     10.625462         -1.444148
# 3      0.002361   0.095956      -8.822786e-16      1.101544          0.903252
# 4      0.137797   0.095956      -8.822786e-16      0.559682         -0.803948
#
#    engine_displacement  engine_type  exterior_color     fleet  frame_damaged  \
# 0            -1.274064    -0.803948        1.110112 -0.354506      -0.070772
# 1            -0.739541    -0.803948        0.259950 -0.354506      -0.070772
# 2            -0.357739    -1.444148        0.298938 -0.354506      -0.070772
# 3             0.024063     0.903252       -0.665916 -0.354506      -0.070772
# 4            -0.739541    -0.803948        0.259950 -0.354506      -0.070772
#
#    ...  theft_title    torque  transmission  transmission_display  trim_name  \
# 0  ...    -0.041934 -0.824244     -0.401772              0.425088   0.032846
# 1  ...    -0.041934  0.097957     -0.401772              0.425088   0.438212
# 2  ...    -0.041934  0.353225      5.379857             -1.144428  -1.026740
# 3  ...    -0.041934  0.701971     -0.401772             -0.135454   1.223364
# 4  ...    -0.041934  0.097957     -0.401772              0.425088   0.438212
#
#    wheel_system  wheel_system_display  wheelbase     width      year
# 0      0.676995              0.703380  -1.181982  0.353710  0.326500
# 1     -0.135281             -1.261386  -0.571057  1.243822  0.592344
# 2     -0.135281             -1.261386  -0.881368  0.244398 -0.471030
# 3     -0.135281             -1.261386   0.078657  1.493677  0.592344
# 4     -0.135281             -1.261386  -0.571057  1.243822  0.592344
#
# [5 rows x 40 columns]

# %%
# Only compute ONCE

scores = calculateMI(df, price_col)
# Out:
# 39  |  year :  [0.57226816]

# %%
size = len(scores)
Y = [s[1][0] for s in scores]
plt.bar(np.arange(0, size), Y)
plt.title("Mutual Information of Each Feature vs Target Column (Price)")
plt.xlabel("Column Indices")
plt.ylabel("Mutual Information")
plt.show()

for i,s in enumerate(scores):
    print(f"{i}: {s[0]}") # Feature names
# Out:
# 0: back_legroom
# 1: body_type
# 2: city_fuel_economy
# 3: daysonmarket
# 4: engine_cylinders
# 5: engine_displacement
# 6: engine_type
# 7: exterior_color
# 8: fleet
# 9: frame_damaged
# 10: franchise_make
# 11: front_legroom
# 12: fuel_tank_volume
# 13: has_accidents
# 14: height
# 15: highway_fuel_economy
# 16: horsepower
# 17: interior_color
# 18: isCab
# 19: is_new
# 20: length
# 21: make_name
# 22: maximum_seating
# 23: mileage
# 24: model_name
# 25: power
# 26: salvage
# 27: savings_amount
# 28: seller_rating
# 29: sp_name
# 30: theft_title
# 31: torque
# 32: transmission
# 33: transmission_display
# 34: trim_name
# 35: wheel_system
# 36: wheel_system_display
# 37: wheelbase
# 38: width
# 39: year

# %%
f_stat, _ = f_regression(df, price_col)

X = np.arange(0, len(f_stat))

plt.figure(figsize=(14,5))
plt.xticks(np.arange(len(f_stat)))
plt.bar(X, f_stat);
plt.title("F-Statistic Scores For Each Column")
plt.xlabel("Columns")
plt.ylabel("F-Statistic")
plt.show()

# %% [markdown]
# Source: https://towardsdatascience.com/how-to-use-variance-thresholding-for-robust-feature-selection-a4503f2b5c3f

# %%
plt.title("Distribution of Seller Ratings for Used Cars")
plt.xlabel("Seller Ratings")
plt.ylabel("Frequencies")
plt.hist(original_df["seller_rating"].dropna().to_numpy());
plt.show()

# %%
# Box plot

df_ = original_df
df_, _ = cleanColumnsAndRows(df_)
df_ = convertColumnsToNumericalAndStandardize(df_, minMaxScaler)

plt.figure(figsize=(20,5))
plt.xticks(np.arange(1,len(df_.columns)+1), df_.columns)
plt.boxplot(df_);
plt.show()

for i,s in enumerate(scores):
    print(f"{i}: {s[0]}") # Feature names
# Out:
# year
# 0: back_legroom
# 1: body_type
# 2: city_fuel_economy
# 3: daysonmarket
# 4: engine_cylinders
# 5: engine_displacement
# 6: engine_type
# 7: exterior_color
# 8: fleet
# 9: frame_damaged
# 10: franchise_make
# 11: front_legroom
# 12: fuel_tank_volume
# 13: has_accidents
# 14: height
# 15: highway_fuel_economy
# 16: horsepower
# 17: interior_color
# 18: isCab
# 19: is_new
# 20: length
# 21: make_name
# 22: maximum_seating
# 23: mileage
# 24: model_name
# 25: power
# 26: salvage
# 27: savings_amount
# 28: seller_rating
# 29: sp_name
# 30: theft_title
# 31: torque
# 32: transmission
# 33: transmission_display
# 34: trim_name
# 35: wheel_system
# 36: wheel_system_display
# 37: wheelbase
# 38: width
# 39: year

# %%
# Exploring range of prices in bins of 1000

plt.figure(figsize=(6,4))
plt.xlim(0,125000)
plt.title("Distribution of Used Car Prices")
plt.xlabel("Prices")
plt.ylabel("Frequencies")
plt.hist(original_df["price"].dropna(), bins=1000);
plt.show()

# %%
# Explore fuel type

fuel_type = original_df["fuel_type"].dropna(axis=0)

plt.figure(figsize=(4,6))
plt.hist(fuel_type, align='left', orientation='horizontal');
plt.title("Distribution of Car Fuel Types")
plt.xlabel("Frequencies")
plt.ylabel("Fuel Types")
plt.show()

# %%
def plotFn(df, label):
    arr = convertMeasurementStrings(df, label)
    
    plt.figure(figsize=(5,4))
    plt.hist(arr)
    plt.title(f"Distribution of Values For {label}")
    plt.xlabel(label)
    plt.ylabel("Frequencies")
    plt.show()

# %%
plotFn(original_df, "back_legroom")

# %%
plotFn(original_df, "front_legroom")

# %%
plotFn(original_df, "height")

# %%
plotFn(original_df, "width")

# %%
plotFn(original_df, "length")

# %%
plotFn(original_df, "wheelbase")
