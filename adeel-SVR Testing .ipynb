# %% [markdown]
# Source: https://github.com/krishnaik06/Advanced-House-Price-Prediction-/blob/master/Feature%20Engineering.ipynb

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
# Imports preprocessing functions
# %run ./v1_jlu_preprocessing.ipynb

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Algorithms

# %%
def predictPrice(X_train, X_test, Y_train, Y_test):
    regr = SVR().fit(X_train, Y_train)
    #regr = Ridge(alpha=100).fit(X_train, Y_train)
    
    train_pred = regr.predict(X_train)
    test_pred = regr.predict(X_test)
    
    print("Train MSE: ", mean_squared_error(Y_train, train_pred))
    print("Test MSE: ", mean_squared_error(Y_test, test_pred))

# %% [markdown]
# ## Code

# %%
begin = time.time()
original_df = pd.read_csv('used_cars_data.csv')
end = time.time()

print("Time taken: ", end - begin)
# Out:
# C:\Users\Adeel\AppData\Local\Temp\ipykernel_20336\1749011710.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv('used_cars_data.csv')
# Time taken:  84.75465965270996

# %%
# Sample a portion of the rows

begin = time.time()
df = original_df.sample(frac=0.30, replace=False, ignore_index=True)
end = time.time()

print("Time taken: ", end - begin)

print(df.shape)
df.head()
# Out:
# Time taken:  1.5143764019012451
# (900012, 66)
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  1GCHSBEA8G1388111      28.6 in  NaN         --      74 in     Pickup Truck
# 1  4S3BNAH6XH3041500      38.1 in  NaN        NaN        NaN            Sedan
# 2  JTHBK1GG3H2251251        40 in  NaN        NaN        NaN            Sedan
# 3  3CZRU5H35LM716248      39.3 in  NaN        NaN        NaN  SUV / Crossover
# 4  1N6ED0EA5LN703724      33.6 in  NaN         --    59.5 in     Pickup Truck
#
#   cabin          city  city_fuel_economy  combine_fuel_economy  ...  \
# 0   NaN  Blue Springs               20.0                   NaN  ...
# 1   NaN      Accident               25.0                   NaN  ...
# 2   NaN        Ramsey               21.0                   NaN  ...
# 3   NaN       El Paso               28.0                   NaN  ...
# 4   NaN       Mcallen                NaN                   NaN  ...
#
#    transmission transmission_display  trimId                       trim_name  \
# 0             A    6-Speed Automatic  t58421  Work Truck Extended Cab LB RWD
# 1             A            Automatic  t68623                    2.5i Premium
# 2             A            Automatic  t69510                         350 FWD
# 3             A            Automatic  t89656                          LX FWD
# 4             A    9-Speed Automatic  t94251                 SV Crew Cab RWD
#
#    vehicle_damage_category wheel_system wheel_system_display wheelbase  \
# 0                      NaN          4X2                  4X2  128.3 in
# 1                      NaN          AWD      All-Wheel Drive  108.3 in
# 2                      NaN          FWD    Front-Wheel Drive    111 in
# 3                      NaN          FWD    Front-Wheel Drive  102.8 in
# 4                      NaN          4X2                  4X2  125.9 in
#
#      width  year
# 0  83.9 in  2016
# 1  81.3 in  2017
# 2  71.7 in  2017
# 3  69.8 in  2020
# 4  72.8 in  2020
#
# [5 rows x 66 columns]

# %% [markdown]
# #### Initial cleaning

# %%
df= cleanColumnsAndRows(df)
# Out:
# (900008, 50)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Process columns with years

# %%
df["year"] = processYears(df)
df.head()
# Out:
#                  vin back_legroom        body_type          city  \
# 0  1GCHSBEA8G1388111      28.6 in     Pickup Truck  Blue Springs
# 1  4S3BNAH6XH3041500      38.1 in            Sedan      Accident
# 2  JTHBK1GG3H2251251        40 in            Sedan        Ramsey
# 3  3CZRU5H35LM716248      39.3 in  SUV / Crossover       El Paso
# 4  1N6ED0EA5LN703724      33.6 in     Pickup Truck       Mcallen
#
#    city_fuel_economy  daysonmarket dealer_zip  \
# 0               20.0             2      64015
# 1               25.0            14      21520
# 2               21.0            22       7446
# 3               28.0            28      79936
# 4                NaN            49      78501
#
#                                          description engine_cylinders  \
# 0  Recent Arrival! 2016 Chevrolet Colorado Work T...               I4
# 1  CARFAX 1-Owner! No Accidents! Premium! AWD! CV...               H4
# 2  CARFAX 1-Owner, GREAT MILES 33,428! FUEL EFFIC...               V6
# 3                                                NaN               I4
# 4  New Price! Front Bucket Seats 4-Way Driver Sea...               V6
#
#    engine_displacement  ...                 torque transmission  \
# 0               2800.0  ...  269 lb-ft @ 4,300 RPM            A
# 1               2500.0  ...  174 lb-ft @ 4,000 RPM            A
# 2               3500.0  ...  248 lb-ft @ 4,700 RPM            A
# 3               1800.0  ...  127 lb-ft @ 4,300 RPM            A
# 4               3800.0  ...  281 lb-ft @ 4,400 RPM            A
#
#    transmission_display  trimId                       trim_name wheel_system  \
# 0     6-Speed Automatic  t58421  Work Truck Extended Cab LB RWD          4X2
# 1             Automatic  t68623                    2.5i Premium          AWD
# 2             Automatic  t69510                         350 FWD          FWD
# 3             Automatic  t89656                          LX FWD          FWD
# 4     9-Speed Automatic  t94251                 SV Crew Cab RWD          4X2
#
#   wheel_system_display wheelbase    width  year
# 0                  4X2  128.3 in  83.9 in    66
# 1      All-Wheel Drive  108.3 in  81.3 in    67
# 2    Front-Wheel Drive    111 in  71.7 in    67
# 3    Front-Wheel Drive  102.8 in  69.8 in    70
# 4                  4X2  125.9 in  72.8 in    70
#
# [5 rows x 50 columns]

# %%
df['year']
# Out:
# 0         66
# 1         67
# 2         67
# 3         70
# 4         70
#           ..
# 900003    70
# 900004    64
# 900005    68
# 900006    68
# 900007    64
# Name: year, Length: 900008, dtype: int64

# %%
scaler = StandardScaler()

# %% [markdown]
# #### Standardize columns of differing data types

# %%
df,price_col = convertColumnsToNumericalAndStandardize(df)
df.head()
# Out:
# year
#    body_type      city  city_fuel_economy  daysonmarket  engine_cylinders  \
# 0  -0.705817 -1.433385      -3.350822e-01     -0.679069         -0.845608
# 1   0.864884 -1.704765       2.909043e-01     -0.568963         -1.332966
# 2   0.864884  0.839133      -2.098849e-01     -0.495559          0.713936
# 3   0.079533 -0.811441       6.664962e-01     -0.440506         -0.845608
# 4  -0.705817  0.165681       4.447902e-16     -0.247821          0.713936
#
#    engine_displacement  engine_type  exterior_color  franchise_dealer  \
# 0            -0.127969    -0.845608        1.340238         -2.066648
# 1            -0.357235    -1.332966        1.322717         -2.066648
# 2             0.406986     0.713936       -0.680003          0.483875
# 3            -0.892191    -0.845608       -0.117555          0.483875
# 4             0.636253     0.713936       -0.339341          0.483875
#
#    franchise_make  ...  model_name  savings_amount  seller_rating   sp_name  \
# 0        1.376852  ...   -0.905356       -0.338186       0.180639  1.542950
# 1        1.376852  ...    0.135240        0.799861       1.431934 -1.609570
# 2       -0.047719  ...   -0.654680       -0.057210      -0.375409  0.857245
# 3       -0.565745  ...   -0.097947       -0.519217       0.871289 -0.632190
# 4        0.535060  ...   -0.319474       -0.519217      -1.737867 -1.348955
#
#    transmission  transmission_display  trim_name  wheel_system  \
# 0     -0.389458             -1.616276   1.244783     -0.925472
# 1     -0.389458              0.624078  -1.811657     -0.193105
# 2     -0.389458              0.624078  -1.462570      0.539261
# 3     -0.389458              0.624078  -0.112492      0.539261
# 4     -0.389458              0.388251   0.763567     -0.925472
#
#    wheel_system_display      year
# 0             -2.041043 -0.416608
# 1             -1.184062 -0.176020
# 2              0.529900 -0.176020
# 3              0.529900  0.545745
# 4             -2.041043  0.545745
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Run algorithm

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

# predictPrice(X_train, X_test, Y_train, Y_test)

#LinReg Result

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

# predictPrice(X_train, X_test, Y_train, Y_test)

# #SVR Result

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

# %%
# param_grid = {'alpha':[1.5,2,2.5,3,3.5,4,10,20,30,40,50,100], 'solver':['auto', 'svd']}

# %%
# grid =  GridSearchCV(predictPrice(X_train, X_test, Y_train, Y_test), param_grid)

# %%
# grid.fit(X_train, Y_train)

# %%
# print(grid.best_params_)
# grid_predictions = grid.predict(X_test)

# %%
predictPrice(X_train, X_test, Y_train, Y_test)
