# %% [markdown]
# Source: https://github.com/krishnaik06/Advanced-House-Price-Prediction-/blob/master/Feature%20Engineering.ipynb

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
# Imports preprocessing functions
# %run ./v1_jlu_preprocessing.ipynb

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Algorithms

# %%
def predictPrice(X_train, X_test, Y_train, Y_test):
    #regr = SVR().fit(X_train, Y_train)
    #regr = Ridge(alpha=100).fit(X_train, Y_train)
    regr = SGDRegressor(max_iter=10000, learning_rate='adaptive',n_iter_no_change=100, alpha=0.0002).fit(X_train,Y_train)
    
    train_pred = regr.predict(X_train)
    test_pred = regr.predict(X_test)
    
    print("Train MSE: ", mean_squared_error(Y_train, train_pred))
    print("Test MSE: ", mean_squared_error(Y_test, test_pred))

    print("Train r2: ", r2_score(Y_train, train_pred))
    print("Test r2: ", r2_score(Y_test, test_pred))

# %% [markdown]
# ## Code

# %%
begin = time.time()
original_df = pd.read_csv('used_cars_data.csv')
end = time.time()

print("Time taken: ", end - begin)
# Out:
# C:\Users\Adeel\AppData\Local\Temp\ipykernel_14316\1749011710.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv('used_cars_data.csv')
# Time taken:  78.71398568153381

# %%
# Sample a portion of the rows

begin = time.time()
df = original_df.sample(frac=0.30, replace=False, ignore_index=True)
end = time.time()

print("Time taken: ", end - begin)

print(df.shape)
df.head()
# Out:
# Time taken:  1.8219010829925537
# (900012, 66)
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACCJABB7JPH68486      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  2T1BURHE0KC240613      41.4 in  NaN        NaN        NaN            Sedan
# 2  3C4NJCBB1LT257033      38.3 in  NaN        NaN        NaN  SUV / Crossover
# 3  4S4BSADC6G3359872      38.1 in  NaN        NaN        NaN            Wagon
# 4  1C4RJFBG4LC423667      38.6 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin         city  city_fuel_economy  combine_fuel_economy  ...  \
# 0   NaN  San Antonio               22.0                   NaN  ...
# 1   NaN  Los Angeles               28.0                   NaN  ...
# 2   NaN     Beaumont               22.0                   NaN  ...
# 3   NaN     Sterling               25.0                   NaN  ...
# 4   NaN   Marysville               18.0                   NaN  ...
#
#    transmission                transmission_display  trimId  \
# 0             A                   9-Speed Automatic  t76091
# 1             A                           Automatic  t78889
# 2             A                           Automatic  t91747
# 3           CVT  Continuously Variable Transmission  t58700
# 4             A                   8-Speed Automatic  t87086
#
#                     trim_name  vehicle_damage_category wheel_system  \
# 0                    Altitude                      NaN          FWD
# 1                          LE                      NaN          FWD
# 2  Sun and Safety Edition FWD                      NaN          FWD
# 3                2.5i Premium                      NaN          AWD
# 4                 Limited 4WD                      NaN          4WD
#
#   wheel_system_display wheelbase    width  year
# 0    Front-Wheel Drive  101.2 in  79.6 in  2018
# 1    Front-Wheel Drive  106.3 in  69.9 in  2019
# 2    Front-Wheel Drive  103.8 in    80 in  2020
# 3      All-Wheel Drive  108.1 in  81.3 in  2016
# 4     Four-Wheel Drive  114.7 in  84.8 in  2020
#
# [5 rows x 66 columns]

# %% [markdown]
# #### Initial cleaning

# %%
df= cleanColumnsAndRows(df)
# Out:
# (900008, 50)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Process columns with years

# %%
df["year"] = processYears(df)
df.head()
# Out:
#                  vin back_legroom        body_type         city  \
# 0  ZACCJABB7JPH68486      35.1 in  SUV / Crossover  San Antonio
# 1  2T1BURHE0KC240613      41.4 in            Sedan  Los Angeles
# 2  3C4NJCBB1LT257033      38.3 in  SUV / Crossover     Beaumont
# 3  4S4BSADC6G3359872      38.1 in            Wagon     Sterling
# 4  1C4RJFBG4LC423667      38.6 in  SUV / Crossover   Marysville
#
#    city_fuel_economy  daysonmarket dealer_zip  \
# 0               22.0            41      78230
# 1               28.0            27      90045
# 2               22.0            49      77701
# 3               25.0            25      20166
# 4               18.0            36      43040
#
#                                          description      engine_cylinders  \
# 0  115V Auxiliary Power Outlet, 3.734 Final Drive...  I4 Flex Fuel Vehicle
# 1  Test drive your selected car on your own for u...                    I4
# 2  Contact Mike Smith Plex Chrysler Jeep Dodge to...                    I4
# 3  2016 Subaru Outback 2.5i Premium AWD Awd, Powe...                    H4
# 4  Diamond Black Crystal Pearlcoat 2020 Jeep Gran...                    V6
#
#    engine_displacement  ...                 torque transmission  \
# 0               2400.0  ...  175 lb-ft @ 3,900 RPM            A
# 1               1800.0  ...  128 lb-ft @ 4,400 RPM            A
# 2               2400.0  ...  175 lb-ft @ 3,900 RPM            A
# 3               2500.0  ...  174 lb-ft @ 4,000 RPM          CVT
# 4               3600.0  ...  390 lb-ft @ 4,250 RPM            A
#
#                  transmission_display  trimId                   trim_name  \
# 0                   9-Speed Automatic  t76091                    Altitude
# 1                           Automatic  t78889                          LE
# 2                           Automatic  t91747  Sun and Safety Edition FWD
# 3  Continuously Variable Transmission  t58700                2.5i Premium
# 4                   8-Speed Automatic  t87086                 Limited 4WD
#
#   wheel_system wheel_system_display wheelbase    width  year
# 0          FWD    Front-Wheel Drive  101.2 in  79.6 in    68
# 1          FWD    Front-Wheel Drive  106.3 in  69.9 in    69
# 2          FWD    Front-Wheel Drive  103.8 in    80 in    70
# 3          AWD      All-Wheel Drive  108.1 in  81.3 in    66
# 4          4WD     Four-Wheel Drive  114.7 in  84.8 in    70
#
# [5 rows x 50 columns]

# %%
df['year']
# Out:
# 0         68
# 1         69
# 2         70
# 3         66
# 4         70
#           ..
# 900003    70
# 900004    69
# 900005    69
# 900006    70
# 900007    68
# Name: year, Length: 900008, dtype: int64

# %%
scaler = StandardScaler()

# %% [markdown]
# #### Standardize columns of differing data types

# %%
df,price_col = convertColumnsToNumericalAndStandardize(df)
df.head()
# Out:
# year
#    body_type      city  city_fuel_economy  daysonmarket  engine_cylinders  \
# 0   0.080768  1.027448          -0.084482     -0.321490         -0.532415
# 1   0.865506  0.020708           0.660682     -0.450482         -0.847658
# 2   0.080768 -1.525273          -0.084482     -0.247780         -0.847658
# 3   2.434982  1.285883           0.288100     -0.468910         -1.373061
# 4   0.080768  0.125625          -0.581258     -0.367559          0.728553
#
#    engine_displacement  engine_type  exterior_color  franchise_dealer  \
# 0            -0.436033    -0.532415       -1.639907         -2.066417
# 1            -0.893853    -0.847658       -0.976211         -2.066417
# 2            -0.436033    -0.847658        0.470816          0.483930
# 3            -0.359730    -1.373061       -0.255045          0.483930
# 4             0.479607     0.728553       -0.719499          0.483930
#
#    franchise_make  ...  model_name  savings_amount  seller_rating   sp_name  \
# 0        1.377022  ...    0.892439       -0.344557       0.579296  0.031306
# 1        1.377022  ...   -0.853416        1.671806       0.066414 -1.449475
# 2       -0.307229  ...   -0.899818       -0.512975      -0.174485  0.483370
# 3        1.117907  ...    0.500927       -0.252439      -0.531948  1.293064
# 4       -0.307229  ...   -0.151594       -0.512975      -0.078245 -0.889810
#
#    transmission  transmission_display  trim_name  wheel_system  \
# 0     -0.389599              0.389370  -1.050330      0.539362
# 1     -0.389599              0.625380  -0.236434      0.539362
# 2     -0.389599              0.625380   0.922704      0.539362
# 3      0.937465              0.743385  -1.813229     -0.192550
# 4     -0.389599             -0.200654  -0.009502     -1.656374
#
#    wheel_system_display      year
# 0              0.529640  0.065236
# 1              0.529640  0.307066
# 2              0.529640  0.548897
# 3             -1.183933 -0.418425
# 4             -0.327147  0.548897
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Run algorithm

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

# predictPrice(X_train, X_test, Y_train, Y_test)

#LinReg Result

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

# predictPrice(X_train, X_test, Y_train, Y_test)

# #SVR Result

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.to_numpy(), price_col.to_numpy(), test_size=0.2)

# %%
# param_grid = {'alpha':[1.5,2,2.5,3,3.5,4,10,20,30,40,50,100], 'solver':['auto', 'svd']}

# %%
# grid =  GridSearchCV(predictPrice(X_train, X_test, Y_train, Y_test), param_grid)

# %%
# grid.fit(X_train, Y_train)

# %%
# print(grid.best_params_)
# grid_predictions = grid.predict(X_test)

# %%
predictPrice(X_train, X_test, Y_train, Y_test)
# Out:
# Train MSE:  177722749.78835636
# Test MSE:  147071172.44254407
# Train r2:  0.5509364097941885
# Test r2:  0.5978825080203756
